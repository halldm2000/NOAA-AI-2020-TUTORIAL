# %% [markdown]
# <a href="https://colab.research.google.com/github/halldm2000/NOAA-AI-2020-TUTORIAL/blob/master/03_CurveFittingPyTorch/CurveFittingPytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Curve Fitting with PyTorch**

# %%
# !git clone -q https://github.com/halldm2000/NOAA-AI-2020-TUTORIAL
# %cd /content/NOAA-AI-2020-TUTORIAL/03_CurveFittingPyTorch/
# Out:
# /content/NOAA-AI-2020-TUTORIAL/03_CurveFittingPyTorch

# %% [markdown]
# ### Read sea ice extent data

# %%
import matplotlib.pyplot as plt
from tutorial import load_extent_data
x,y = load_extent_data()

plt.figure(figsize=(12,6))
plt.plot(x%365,y,'.',alpha = 0.2);
plt.xlabel("day")
plt.ylabel("Artic sea ice extent 10$^6$ sq km ");

# %%
# Out:
# array([298.41666667, 300.41666667, 302.41666667, ...,   0.        ,
#          0.        ,   0.        ])
